# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# # Tensor datatypes
#
# **Note:** Tensor datatypes is one of the 3 big error with pytorch and deeplearning
# 1. Tensor not right datatype
# 2. Tensor not right shape
# 3. Tensor not on the right device

# %%
# Float 32 tensor
float_32_tensor = torch.tensor([3.0, 6.0, 9.0],
                               dtype=None,# what datatype is the tensor (e.g float32 float16)
                               device="cpu",#  Defing what it should the processor be "cpu" or "gpu"
                               requires_grad=False # Whether or not to track gradients with this tensors operation
                               ) 
float_32_tensor
# Out:
# tensor([3., 6., 9.])

# %%
float_32_tensor.dtype
# Out:
# torch.float32

# %%
float_16_tensor = float_32_tensor.type(torch.float16)
float_16_tensor
# Out:
# tensor([3., 6., 9.], dtype=torch.float16)

# %%
combined_tensor = float_16_tensor*float_32_tensor
combined_tensor.dtype
# Out:
# torch.float32

# %% [markdown]
# ### Gettting information from tensors (tenosr attribute)
# 1. Tensor not right datatype - to do get datatype from a  tensor,can use `tensor.dtype`
# 2. Tensor not right shape - to get shape from a tensor, can use `tensor.shape`
# 3. Tensor not on the right device - to get device from a tensor,can use `tensor.device`

# %%
# Create a tensor
some_tensor32 = torch.rand((3,4))
some_tensor16 = some_tensor32.type(torch.float16)*1000//1

# %%
# Find out details about some tensor
print(some_tensor16)
print(f"Datatype of tensor: {some_tensor16.dtype}")
print(f"Shape of Tensor: {some_tensor16.shape}")
print(f"Device tensro is on:{some_tensor16.device}")
# Out:
# tensor([[225.,  60., 710., 940.],
#         [ 58.,  20., 232.,  48.],
#         [258., 482., 614., 139.]], dtype=torch.float16)
# Datatype of tensor: torch.float16
# Shape of Tensor: torch.Size([3, 4])
# Device tensro is on:cpu

# %% [markdown]
# ### Manipulating Tensors (tensor operations)
#
# Tensor operations include:
# * Addition
# * Subtraction
# * Multiplication (element-wise)
# * Division
# * Matrix multiplication

# %% [markdown]
# ### Matrix multiplication
# Two main ways of performing multiplication in neural networks and deep learning
# 1. Element-wise multiplication
#
# 2. Matrix multiplication (dot product)
#
# There are two main rules that performing matrix multiplication needs to satisfy:
# 1. The  **inner dimentions** must match:
# * ` (3,2) @ (3,2)` won't work
# * ` (2,3) @ (3,2) ` will work
# * ` (3,2) @ (2,3) ` will work
# 2. The resulting matrix has the shape of the **outer dimention**
# * ` (2,3) @ (3,2) ` -> `(2,2)`
# * ` (3,2) @ (2,3) ` -> `(2,3)`

# %%
# %time
MATRIX_1 = torch.tensor(range(1,1000000))
torch.matmul(MATRIX_1,MATRIX_1)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.34 μs
# tensor(333332833333500000)

# %%
# %time
value = 0
for i in range(len(MATRIX_1)):
    value += MATRIX_1[i] * MATRIX_1[i]
value
# Out:
# CPU times: total: 0 ns
# Wall time: 6.91 μs
# tensor(333332833333500000)

# %% [markdown]
# ### One of the most common errors in deep learning: shape errors

# %%
torch.matmul(torch.rand(3,2),torch.rand(2,2))
# Out:
# tensor([[0.7195, 1.1832],
#         [0.6958, 1.1031],
#         [0.6471, 1.1593]])

# %%
# Shape for matrix multiplication
tensor_A = torch.tensor([[1, 2], [3, 4], [5, 6]])
tensor_B = torch.tensor([[7, 10], [8, 11], [9, 12]])

# %%
tensor_A.shape,tensor_B.shape
# Out:
# (torch.Size([3, 2]), torch.Size([3, 2]))

# %% [markdown]
# To fix our tensor shape issues we can manipulate the shape of one of our tensors using a **transpose**.
#
#
# A **transpose** switches the axes or dimention of a given tensor

# %%
tensor_B.T
# Out:
# tensor([[ 7,  8,  9],
#         [10, 11, 12]])

# %%
tensor_B.T,tensor_B.T.shape
# Out:
# (tensor([[ 7,  8,  9],
#          [10, 11, 12]]),
#  torch.Size([2, 3]))

# %%
tensor_B,tensor_B.shape
# Out:
# (tensor([[ 7, 10],
#          [ 8, 11],
#          [ 9, 12]]),
#  torch.Size([3, 2]))

# %%
torch.matmul(tensor_A,tensor_B.T)
# Out:
# tensor([[ 27,  30,  33],
#         [ 61,  68,  75],
#         [ 95, 106, 117]])
